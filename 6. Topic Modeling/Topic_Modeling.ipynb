# %%
# !pip install --upgrade --pre pythainlp
# !pip install pyLDAvis

# %%
import pandas as pd
import pythainlp
import gensim
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df=pd.read_csv('/content/Skooldio_Review.csv')

# %%
df.tail()
# Out:
#                                                Review
# 8   เกินความคาดหวังมาก ด้วยกับราคาคอร์สเท่านี้ โดย...
# 9   อธิบายและยกตัวอย่างเข้าใจง่ายมากๆ การแบ่งคลิปเ...
# 10  อาจารย์ทั้งสองท่านอธิบายดี มีตัวอย่างให้ดูตลอด...
# 11  แนวๆ Intro ว่าเกี่ยวกับกราฟประเภทต่างๆ วิธีการ...
# 12  อยากให้ตรงที่เป็นแบบฝึกหัด มีการอธิบายมากขึ้น ...

# %%
#Tokenize Words
stopwords = list(pythainlp.corpus.thai_stopwords())
removed_words = ['การอธิบาย','สำหรับ','การนำ','มากขึ้น','สนใจ','ซ้ำ','ดู','จุด','ที่จะ','คอร์ส','ชอบ','ดีกว่า','ทำ','ที่นั่น','ที่','',' ','  ','    ','     ','      ','\n','ค่ะ','คะ','นะคะ','ๆ','('')','(',')','(' ,')','(' , ')','(', ')','ๆ','มาก','รู้สึก','ดี','ดีมาก','มากๆ','มี','ยังมี']
screening_words = stopwords + removed_words

def tokenize_with_space(sentence):
    merged = ''
    words = pythainlp.word_tokenize(str(sentence), engine='longest')
    for word in words:
        if word not in screening_words:
            merged = merged + ',' + word
    return merged[1:]

# %%
df['Review_tokenized'] = df['Review'].apply(lambda x: tokenize_with_space(x))

# %%
df
# Out:
#                                                Review  \
# 0   เนื้อหาครอบคลุมตั้งแต่หลักการออกแบบ dashboard ...
# 1   คอร์สนี้สอนให้เข้าใจหลักการเบื้องต้นในการทำ Da...
# 2   ได้เห็นภาพรวมคร่าวๆ การยกตัวอย่างการนำไปใช้ ใน...
# 3   สิ่งที่คอร์สนี้สอนน่าจะเป็นสิ่งที่สำคัญมากที่ส...
# 4   การเรียนครั้งนี้ ช่วยให้ได้รับความรู้ในการจัดท...
# 5   ทำให้เข้าใจในการออกแบบทำกราฟมากขึ้นกว่าเดิมเปล...
# 6   เข้าใจมากขึ้นสำหรับความแตกต่างของการเลือกใช้ ร...
# 7   เป็นคอร์สที่เหมาะกับผู้สนใจเกี่ยวกับ data visu...
# 8   เกินความคาดหวังมาก ด้วยกับราคาคอร์สเท่านี้ โดย...
# 9   อธิบายและยกตัวอย่างเข้าใจง่ายมากๆ การแบ่งคลิปเ...
# 10  อาจารย์ทั้งสองท่านอธิบายดี มีตัวอย่างให้ดูตลอด...
# 11  แนวๆ Intro ว่าเกี่ยวกับกราฟประเภทต่างๆ วิธีการ...
# 12  อยากให้ตรงที่เป็นแบบฝึกหัด มีการอธิบายมากขึ้น ...
#
#                                      Review_tokenized
# 0   เนื้อหา,ครอบคลุม,หลักการ,ออกแบบ,dashboard,ในแง...
# 1   สอน,หลักการ,เบื้องต้น,dashboard,เข้าใจง่าย,ควา...
# ...

# %%
#Create Dictionary
documents = df['Review_tokenized'].to_list()
texts = [[text for text in doc.split(',')] for doc in documents]
dictionary = gensim.corpora.Dictionary(texts)

# %%
print(dictionary.token2id.keys())
# Out:
# dict_keys(['balance', 'card', 'concept', 'dashboard', 'design', 'indicator', 'junior', 'kpi', 'score', 'user', 'ครอบคลุม', 'ความรู้', 'ความเข้าใจ', 'จุดเริ่มต้น', 'ตัวอย่าง', 'ทำความเข้าใจ', 'ภาพรวม', 'สายงาน', 'หลักการ', 'อธิบาย', 'ออกแบบ', 'เนื้อหา', 'ในแง่', 'ไปหา', 'bi', 'power', 'tools', 'การเรียนรู้', 'ความต้องการ', 'จังหวะ', 'ฐาน', 'ต่อไป', 'ที่มา', 'ปูพื้น', 'วิธีการ', 'สอน', 'อาจารย์', 'เข้าใจง่าย', 'เบื้องต้น', 'เรียน', 'เรื่อง', 'business', 'case', 'ข้อควรระวัง', 'คน', 'คร่าวๆ', 'คำนึง', 'ตรวจสอบ', 'ปรับปรุง', 'ยกตัวอย่าง', 'ระวัง', 'สังเกต', 'หลัก', 'หลากหลาย', 'องค์กร', 'อยู่แล้ว', 'เกณฑ์', 'เป็นหลัก', 'เห็นภาพ', 'เอาไว้', 'data', 'db', 'กลับมา', 'กลุ่มเป้าหมาย', 'การทำงาน', 'คนใช้', 'ทำให้เกิด', 'น่าจะเป็น', 'ประโยชน์', 'รสื่ง', 'วิเคราะห์', 'สา', 'สื่อ', 'ออกมา', 'เป็นหนึ่ง', 'แน่นอน', 'โดยเฉพาะ', 'กราฟ', 'การเรียน', 'การใช้งาน', 'ความน่าสนใจ', 'ความสัมพันธ์', 'ตอบ', 'ประเด็น', 'มุม', 'เป็นความ', 'เสนอ', 'โจทย์', 'ให้การ', 'ให้ได้', 'คำถาม', 'ตอบคำถาม', 'มุมมอง', 'เดิม
# ...

# %%
gensim_corpus = [dictionary.doc2bow(text, allow_update=True) for text in texts]
word_frequencies = [[(dictionary[id], frequence) for id, frequence in couple] for couple in gensim_corpus]

# %%
#Topic Modeling
num_topics = 2
chunksize = 2000 # size of the doc looked at every pass
passes = 50 # number of passes through documents
iterations = 50
eval_every =1 # Don't evaluate model perplexity, takes too much time

#make a index to word dictionary
temp = dictionary[0] #This is only to load the dictionary
id2word = dictionary.id2token

# %time model = gensim.models.LdaModel(corpus=gensim_corpus, id2word=id2word, chunksize=chunksize, \
                                    alpha='auto', eta='auto', \
                                    iterations=iterations, num_topics=num_topics, \
                                    passes=passes, eval_every=eval_every)
# Out:
# CPU times: user 243 ms, sys: 0 ns, total: 243 ms
# Wall time: 245 ms

# %%
pyLDAvis.gensim.prepare(model, gensim_corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 1      0.064629  0.0       1        1  66.128935
# 0     -0.064629  0.0       2        1  33.871065, topic_info=              Term      Freq     Total Category  logprob  loglift
# 77            กราฟ  3.000000  3.000000  Default  30.0000  30.0000
# 128        พื้นฐาน  1.000000  1.000000  Default  29.0000  29.0000
# 107       เหมาะกับ  1.000000  1.000000  Default  28.0000  28.0000
# 102  visualization  1.000000  1.000000  Default  27.0000  27.0000
# 82             ตอบ  1.000000  1.000000  Default  26.0000  26.0000
# ..             ...       ...       ...      ...      ...      ...
# 40          เรื่อง  0.710525  2.303791   Topic2  -4.4849  -0.0937
# 33          ปูพื้น  0.710525  1.666479   Topic2  -4.4849   0.2301
# 34         วิธีการ  0.710525  1.666479   Topic2  -4.4849   0.2301
# 36         อาจารย์  0.710525  1.666479   Topic2  -4.4849   0.2301
# ...

# %%
model.show_topic(0)
# Out:
# [('กราฟ', 0.048872314),
#  ('คน', 0.018796986),
#  ('อธิบาย', 0.018796986),
#  ('data', 0.018796975),
#  ('พื้นฐาน', 0.018796971),
#  ('เหมาะกับ', 0.01879697),
#  ('visualization', 0.018796967),
#  ('ตอบ', 0.018796965),
#  ('เนื้อหา', 0.011278163),
#  ('ออกแบบ', 0.011278156)]

# %%
model.show_topic(1)
# Out:
# [('dashboard', 0.028497607),
#  ('user', 0.018134806),
#  ('อธิบาย', 0.018134806),
#  ('หลักการ', 0.018134804),
#  ('เนื้อหา', 0.018134799),
#  ('ข้อมูล', 0.0129534025),
#  ('โดยเฉพาะ', 0.0129534),
#  ('เรื่อง', 0.0129534),
#  ('เข้าใจง่าย', 0.012953399),
#  ('ความเข้าใจ', 0.012953399)]

# %%
df['topics'] = df['Review_tokenized'].apply(lambda x: model.get_document_topics(dictionary.doc2bow(x.split(',')))[0][0])
df['score'] = df['Review_tokenized'].apply(lambda x: model.get_document_topics(dictionary.doc2bow(x.split(',')))[0][1])

# %%
df
# Out:
#                                                Review  \
# 0   เนื้อหาครอบคลุมตั้งแต่หลักการออกแบบ dashboard ...
# 1   คอร์สนี้สอนให้เข้าใจหลักการเบื้องต้นในการทำ Da...
# 2   ได้เห็นภาพรวมคร่าวๆ การยกตัวอย่างการนำไปใช้ ใน...
# 3   สิ่งที่คอร์สนี้สอนน่าจะเป็นสิ่งที่สำคัญมากที่ส...
# 4   การเรียนครั้งนี้ ช่วยให้ได้รับความรู้ในการจัดท...
# 5   ทำให้เข้าใจในการออกแบบทำกราฟมากขึ้นกว่าเดิมเปล...
# 6   เข้าใจมากขึ้นสำหรับความแตกต่างของการเลือกใช้ ร...
# 7   เป็นคอร์สที่เหมาะกับผู้สนใจเกี่ยวกับ data visu...
# 8   เกินความคาดหวังมาก ด้วยกับราคาคอร์สเท่านี้ โดย...
# 9   อธิบายและยกตัวอย่างเข้าใจง่ายมากๆ การแบ่งคลิปเ...
# 10  อาจารย์ทั้งสองท่านอธิบายดี มีตัวอย่างให้ดูตลอด...
# 11  แนวๆ Intro ว่าเกี่ยวกับกราฟประเภทต่างๆ วิธีการ...
# 12  อยากให้ตรงที่เป็นแบบฝึกหัด มีการอธิบายมากขึ้น ...
#
#                                      Review_tokenized  topics     score
# 0   เนื้อหา,ครอบคลุม,หลักการ,ออกแบบ,dashboard,ในแง...       1  0.998966
# ...
